# %% [markdown]
# **import library**

# %%
import pandas as pd

# %% [markdown]
# **Reading data**

# %%
df=pd.read_csv("/content/Churn_Modelling.csv")

# %% [markdown]
# **Checking data structure**

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# **Checking columns**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# **Data** **cleaning**

# %% [markdown]
# Checking null

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# Remove the columns that is not needed for the analysis.

# %%
df.drop(columns=['RowNumber','CustomerId','Surname'],inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# Checking duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# which countries in data
df.Geography.unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
# gender count
df.value_counts('Gender')
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
# geography count
df.value_counts('Geography')
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# **EDA**

# %%
df.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000    10000.000000     10000.000000  10000.000000
# mean       0.70550        0.515100    100090.239881      0.203700
# std        0.45584        0.499797     57510.492818      0.402769
# min        0.00000        0.000000        11.580000      0.000000
# 25%        0.00000        0.000000     51002.110000      0.000000
# 50%        1.00000        1.000000    100193.915000      0.000000
# 75%        1.00000        1.000000    149388.247500      0.000000
# max        1.00000        1.000000    199992.480000      1.000000

# %%
# churn count
df["Exited"].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
# churn percentage
churn_percentage=(df["Exited"].value_counts()[1]/df["Exited"].count())*100
churn_percentage
# Out:
# np.float64(20.369999999999997)

# %%
# geography wise churn rate
Geography_churn=df.groupby('Geography')['Exited'].mean()*100
Geography_churn
# Out:
# Geography
# France     16.154767
# Germany    32.443204
# Spain      16.673395
# Name: Exited, dtype: float64

# %% [markdown]
# purely in terms of geography, the highest churn rate is from germany

# %%
# gender wise churn rate
Gender_churn=df.groupby('Gender')['Exited'].mean()*100
Gender_churn
# Out:
# Gender
# Female    25.071539
# Male      16.455928
# Name: Exited, dtype: float64

# %% [markdown]
# when looking solely at gender,the churn rate is highest among females

# %%
def Age_group(Age):
   if Age<=25:
    return "18-25"
   elif Age<=35:
    return "26-35"
   elif Age<=50:
    return "36-50"
   elif Age<=65:
    return "51-65"
   else:
    return "66+"
df["Age_group"]=df["Age"].apply(Age_group)

# %% [markdown]
# create age group column

# %%
df[["Age","Age_group"]].head(10)
# Out:
#    Age Age_group
# 0   42     36-50
# 1   41     36-50
# 2   42     36-50
# 3   39     36-50
# 4   43     36-50
# 5   44     36-50
# 6   50     36-50
# 7   29     26-35
# 8   44     36-50
# 9   27     26-35

# %%
df['Age_group'].value_counts()
# Out:
# Age_group
# 36-50    4586
# 26-35    3542
# 51-65     997
# 18-25     611
# 66+       264
# Name: count, dtype: int64

# %%
Age_group_churn=df.groupby('Age_group')['Exited'].mean()*100
Age_group_churn
# Out:
# Age_group
# 18-25     7.528642
# 26-35     8.498024
# 36-50    24.574793
# 51-65    52.958877
# 66+      13.257576
# Name: Exited, dtype: float64

# %% [markdown]
# if we look at it by Age group , the highest churn rate is in the 51-65 age group

# %%
# Active member wise churn
Active_churn=df.groupby('IsActiveMember')['Exited'].mean()*100
Active_churn
# Out:
# IsActiveMember
# 0    26.850897
# 1    14.269074
# Name: Exited, dtype: float64

# %% [markdown]
# when looking solely at active members, the churn rate is highest among inactive member

# %%
# number of product wise churn rate
product_churn=df.groupby('NumOfProducts')['Exited'].mean()*100
product_churn
# Out:
# NumOfProducts
# 1     27.714398
# 2      7.581699
# 3     82.706767
# 4    100.000000
# Name: Exited, dtype: float64

# %%
# age and geography wise churn rate
age_geo_churn=df.groupby(['Age_group','Geography'])['Exited'].mean()*100
age_geo_churn
# Out:
# Age_group  Geography
# 18-25      France        5.228758
#            Germany      11.188811
#            Spain         8.641975
# 26-35      France        5.788635
#            Germany      14.800995
#            Spain         8.538012
# 36-50      France       20.026942
#            Germany      38.640133
#            Spain        18.647008
# 51-65      France       48.817204
#            Germany      67.465753
#            Spain        43.333333
# 66+        France        9.022556
#            Germany      25.000000
#            Spain        10.447761
# Name: Exited, dtype: float64

# %% [markdown]
# The churn rate is highest among 51-65 age group in germany

# %%
df["CreditScore"].max()
# Out:
# 850

# %%
df["CreditScore"].min()
# Out:
# 350

# %%
def Credit_score_group(CreditScore):
   if CreditScore<=500:
    return "low"
   elif CreditScore<=650:
    return "medium"
   else:
    return "high"
df["CreditScore_group"]=df["CreditScore"].apply(Credit_score_group)

# %% [markdown]
# create creditscore group column

# %%
df[["CreditScore","CreditScore_group"]].head(10)
# Out:
#    CreditScore CreditScore_group
# 0          619            medium
# 1          608            medium
# 2          502            medium
# 3          699              high
# 4          850              high
# 5          645            medium
# 6          822              high
# 7          376               low
# 8          501            medium
# 9          684              high

# %%
df['CreditScore_group'].value_counts()
# Out:
# CreditScore_group
# high      5063
# medium    4294
# low        643
# Name: count, dtype: int64

# %%
# credit score group wise churn rate
df.groupby("CreditScore_group")["Exited"].mean()*100
# Out:
# CreditScore_group
# high      19.356113
# low       23.639191
# medium    21.075920
# Name: Exited, dtype: float64

# %% [markdown]
# Customers with lower credit scores show a slightly higher churn rate, but the difference across credit-score groups is relatively small.

# %%
categorical_cols = [
    'Geography',
    'Gender',
    'HasCrCard',
    'IsActiveMember',
    'NumOfProducts',
    'Tenure',
    'Age_group',
    'CreditScore_group'
]

for col in categorical_cols:
    print(f"\n--- Churn Rate by {col} ---")
    print((df.groupby(col)['Exited'].mean() * 100).round(2))
# Out:
# --- Churn Rate by Geography ---
# Geography
# France     16.15
# Germany    32.44
# Spain      16.67
# Name: Exited, dtype: float64
#
# --- Churn Rate by Gender ---
# Gender
# Female    25.07
# Male      16.46
# Name: Exited, dtype: float64
#
# --- Churn Rate by HasCrCard ---
# HasCrCard
# 0    20.81
# 1    20.18
# Name: Exited, dtype: float64
#
# --- Churn Rate by IsActiveMember ---
# IsActiveMember
# 0    26.85
# 1    14.27
# Name: Exited, dtype: float64
#
# --- Churn Rate by NumOfProducts ---
# NumOfProducts
# 1     27.71
# 2      7.58
# 3     82.71
# 4    100.00
# Name: Exited, dtype: float64
#
# --- Churn Rate by Tenure ---
# Tenure
# 0     23.00
# 1     22.42
# 2     19.18
# 3     21.11
# 4     20.53
# 5     20.65
# 6     20.27
# 7     17.22
# 8     19.22
# 9     21.65
# 10    20.61
# Name: Exited, dtype: float64
#
# --- Churn Rate by Age_group ---
# Age_group
# 18-25     7.53
# 26-35     8.50
# 36-50    24.57
# 51-65    52.96
# 66+      13.26
# Name: Exited, dtype: float64
#
# --- Churn Rate by CreditScore_group ---
# CreditScore_group
# high      19.36
# low       23.64
# medium    21.08
# Name: Exited, dtype: float64

# %%
numerical_cols = [
    'CreditScore',
    'Age',
    'Tenure',
    'Balance',
    'NumOfProducts',
    'EstimatedSalary'
]

df.groupby('Exited')[numerical_cols].mean().round(2)
# Out:
#         CreditScore    Age  Tenure   Balance  NumOfProducts  EstimatedSalary
# Exited
# 0            651.85  37.41    5.03  72745.30           1.54         99738.39
# 1            645.35  44.84    4.93  91108.54           1.48        101465.68

# %%
df["Balance"].agg(['min','max','mean','median'])
# Out:
# min            0.000000
# max       250898.090000
# mean       76485.889288
# median     97198.540000
# Name: Balance, dtype: float64

# %%
def Balance_group(Balance):
  if Balance==0:
    return "No Balance"
  elif Balance<=50000:
    return "Low"
  elif Balance<=100000:
    return "Medium"
  elif Balance<=150000:
    return "High"
  else:
    return "Very High"
df["Balance_group"]=df["Balance"].apply(Balance_group)

# %% [markdown]
# create balance group column

# %%
df[["Balance","Balance_group"]].head()
# Out:
#      Balance Balance_group
# 0       0.00    No Balance
# 1   83807.86        Medium
# 2  159660.80     Very High
# 3       0.00    No Balance
# 4  125510.82          High

# %%
# Balance wise churn rate
Balance_churn=df.groupby('Balance_group')['Exited'].mean().mul(100).round(2)
Balance_churn
# Out:
# Balance_group
# High          25.77
# Low           34.67
# Medium        19.88
# No Balance    13.82
# Very High     23.12
# Name: Exited, dtype: float64

# %% [markdown]
# in terms of balance , the churn rate is higher among those with low balances

# %%
df["HasCrCard"].value_counts()
# Out:
# HasCrCard
# 1    7055
# 0    2945
# Name: count, dtype: int64

# %%
# hascrcard wise churn rate
df.groupby('HasCrCard')['Exited'].mean().mul(100).round(2)
# Out:
# HasCrCard
# 0    20.81
# 1    20.18
# Name: Exited, dtype: float64

# %%
df.groupby("HasCrCard")["Exited"].sum()
# Out:
# HasCrCard
# 0     613
# 1    1424
# Name: Exited, dtype: int64

# %%
# In which country is the churn rate higher for a specific age group?
pd.crosstab(
    [df['Age_group'], df['Geography']],
    df['Exited'],
    normalize='index'
).mul(100).round(2)
# Out:
# Exited                   0      1
# Age_group Geography
# 18-25     France     94.77   5.23
#           Germany    88.81  11.19
#           Spain      91.36   8.64
# 26-35     France     94.21   5.79
#           Germany    85.20  14.80
#           Spain      91.46   8.54
# 36-50     France     79.97  20.03
#           Germany    61.36  38.64
#           Spain      81.35  18.65
# 51-65     France     51.18  48.82
#           Germany    32.53  67.47
#           Spain      56.67  43.33
# 66+       France     90.98   9.02
#           Germany    75.00  25.00
#           Spain      89.55  10.45

# %% [markdown]
# In Germany, the churn rate is high among the 51–65 age group.

# %%
# Which group has a higher churn rate based on age group and active membership?
pd.crosstab(
    [df['Age_group'], df['IsActiveMember']],
    df['Exited'],
    normalize='index'
).mul(100).round(2)
# Out:
# Exited                        0      1
# Age_group IsActiveMember
# 18-25     0               88.89  11.11
#           1               95.67   4.33
# 26-35     0               89.20  10.80
#           1               93.73   6.27
# 36-50     0               69.91  30.09
#           1               81.46  18.54
# 51-65     0               13.23  86.77
#           1               69.04  30.96
# 66+       0               37.50  62.50
#           1               93.53   6.47

# %% [markdown]
# The churn rate is high among inactive members and in the 51–65 age group.

# %%
# credit score group and geography wise churn rate and retained rate
pd.crosstab(
    [df['CreditScore_group'], df['Geography']],
    df['Exited'],
    normalize='index'
).mul(100).round(2)
# Out:
# Exited                           0      1
# CreditScore_group Geography
# high              France     84.93  15.07
#                   Germany    68.78  31.22
#                   Spain      83.83  16.17
# low               France     80.36  19.64
#                   Germany    64.94  35.06
#                   Spain      81.16  18.84
# medium            France     83.08  16.92
#                   Germany    66.54  33.46
#                   Spain      83.03  16.97

# %% [markdown]
# The churn rate is high among low creditscore group in germany

# %%
# Balance group and geography
pd.crosstab(
    [df['Balance_group'], df['Geography']],
    df['Exited'],
    normalize='index'
).mul(100).round(2)
# Out:
# Exited                        0      1
# Balance_group Geography
# High          France      83.88  16.12
#               Germany     60.90  39.10
#               Spain       85.33  14.67
# Low           France      51.22  48.78
#               Germany    100.00   0.00
#               Spain       60.00  40.00
# Medium        France      83.00  17.00
#               Germany     79.39  20.61
#               Spain       75.74  24.26
# No Balance    France      86.06  13.94
#               Spain       86.41  13.59
# Very High     France      75.69  24.31
#               Germany     80.89  19.11
#               Spain       73.54  26.46

# %% [markdown]
# Churn rates vary across balance groups and geographies. Germany shows relatively higher churn in the High Balance group, while some Low Balance segments have high churn rates but very small customer counts. Therefore, these smaller segments should be interpreted cautiously.

# %%
df["Balance_group"].value_counts()
# Out:
# Balance_group
# High          3830
# No Balance    3617
# Medium        1509
# Very High      969
# Low             75
# Name: count, dtype: int64

# %%
df.groupby(['Balance_group', 'Geography']).size()
# Out:
# Balance_group  Geography
# High           France       1476
#                Germany      1652
#                Spain         702
# Low            France         41
#                Germany        19
#                Spain          15
# Medium         France        647
#                Germany       524
#                Spain         338
# No Balance     France       2418
#                Spain        1199
# Very High      France        432
#                Germany       314
#                Spain         223
# dtype: int64

# %%
df['NumOfProducts'].value_counts()
# Out:
# NumOfProducts
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: count, dtype: int64

# %%
# number of products and active member
pd.crosstab(
    [df['NumOfProducts'], df['IsActiveMember']],
    df['Exited'],
    normalize='index'
).mul(100).round(2)
# Out:
# Exited                            0       1
# NumOfProducts IsActiveMember
# 1             0               63.35   36.65
#               1               81.08   18.92
# 2             0               90.11    9.89
#               1               94.44    5.56
# 3             0               11.76   88.24
#               1               24.78   75.22
# 4             0                0.00  100.00
#               1                0.00  100.00

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Churn rate by geography
plt.figure(figsize=(7, 4.5))

geo_churn = df.groupby('Geography')['Exited'].mean().mul(100).round(2)

ax = sns.barplot(
    x=geo_churn.index,
    y=geo_churn.values
)

plt.title('Customer Churn Rate by Geography', fontsize=14)
plt.xlabel('Geography')
plt.ylabel('Churn Rate (%)')
plt.ylim(0, max(geo_churn.values) + 8)

for i, value in enumerate(geo_churn.values):
    ax.text(i, value + 1, f'{value:.1f}%', ha='center')

plt.grid(False)
plt.tight_layout()
plt.show()

print(" What I Found:")
print("Germany has the highest churn rate at approximately 32.4%, "
      "while France and Spain have churn rates of around 16%.")
# Out:
#  What I Found:
# Germany has the highest churn rate at approximately 32.4%, while France and Spain have churn rates of around 16%.

# %%
# Churn rate by age group
age_order = ['18-25', '26-35', '36-50', '51-65', '66+']

age_churn = (
    df.groupby('Age_group')['Exited']
    .mean()
    .mul(100)
    .reindex(age_order)
)

plt.figure(figsize=(8, 4.5))

ax = sns.barplot(
    x=age_churn.index,
    y=age_churn.values
)

plt.title('Customer Churn Rate by Age Group', fontsize=14)
plt.xlabel('Age Group')
plt.ylabel('Churn Rate (%)')
plt.ylim(0, max(age_churn.values) + 8)

for i, value in enumerate(age_churn.values):
    ax.text(i, value + 1, f'{value:.1f}%', ha='center')

plt.grid(False)
plt.tight_layout()
plt.show()

print(" What I Found:")
print("Churn increases substantially with age, with the 51-65 age group "
      "showing the highest churn rate of approximately 53%.")
# Out:
#  What I Found:
# Churn increases substantially with age, with the 51-65 age group showing the highest churn rate of approximately 53%.

# %%
# Churn rate by active membership
active_churn = (
    df.groupby('IsActiveMember')['Exited']
    .mean()
    .mul(100)
)

active_churn.index = ['Inactive', 'Active']

plt.figure(figsize=(7, 4.5))

ax = sns.barplot(
    x=active_churn.index,
    y=active_churn.values
)

plt.title('Customer Churn Rate by Active Membership', fontsize=14)
plt.xlabel('Membership Status')
plt.ylabel('Churn Rate (%)')
plt.ylim(0, max(active_churn.values) + 8)

for i, value in enumerate(active_churn.values):
    ax.text(i, value + 1, f'{value:.1f}%', ha='center')

plt.grid(False)
plt.tight_layout()
plt.show()

print("What I Found:")
print("Inactive members have a higher churn rate (approximately 26.9%) "
      "compared with active members (approximately 14.3%).")
# Out:
# What I Found:
# Inactive members have a higher churn rate (approximately 26.9%) compared with active members (approximately 14.3%).

# %%
# Churn rate by number of products
product_churn = (
    df.groupby('NumOfProducts')['Exited']
    .mean()
    .mul(100)
)

plt.figure(figsize=(8, 4.5))

ax = sns.barplot(
    x=product_churn.index.astype(str),
    y=product_churn.values
)

plt.title('Customer Churn Rate by Number of Products', fontsize=14)
plt.xlabel('Number of Products')
plt.ylabel('Churn Rate (%)')
plt.ylim(0, 110)

for i, value in enumerate(product_churn.values):
    ax.text(i, value + 2, f'{value:.1f}%', ha='center')

plt.grid(False)
plt.tight_layout()
plt.show()

print(" What I Found:")
print("Customers with 1 product have a churn rate of approximately 27.7%, "
      "while customers with 2 products have a much lower churn rate of "
      "approximately 7.6%. The 3- and 4-product groups show very high "
      "churn rates and should be interpreted along with their customer counts.")
# Out:
#  What I Found:
# Customers with 1 product have a churn rate of approximately 27.7%, while customers with 2 products have a much lower churn rate of approximately 7.6%. The 3- and 4-product groups show very high churn rates and should be interpreted along with their customer counts.

# %%
# churn rate by gender
gender_churn = (
    df.groupby('Gender')['Exited']
    .mean()
    .mul(100)
)

plt.figure(figsize=(7, 4.5))

ax = sns.barplot(
    x=gender_churn.index,
    y=gender_churn.values
)

plt.title('Customer Churn Rate by Gender', fontsize=14)
plt.xlabel('Gender')
plt.ylabel('Churn Rate (%)')
plt.ylim(0, max(gender_churn.values) + 8)

for i, value in enumerate(gender_churn.values):
    ax.text(i, value + 1, f'{value:.1f}%', ha='center')

plt.grid(False)
plt.tight_layout()
plt.show()

print(" What I Found:")
print("The churn rate differs between male and female customers, "
      "indicating that gender may be useful for further segmentation.")
# Out:
#  What I Found:
# The churn rate differs between male and female customers, indicating that gender may be useful for further segmentation.

# %%
#Age group and geography - churn rate
age_geo_churn = (
    df.groupby(['Age_group', 'Geography'])['Exited']
    .mean()
    .mul(100)
    .reset_index()
)

plt.figure(figsize=(9, 5))

ax = sns.barplot(
    data=age_geo_churn,
    x='Age_group',
    y='Exited',
    hue='Geography'
)

plt.title('Churn Rate by Age Group and Geography', fontsize=14)
plt.xlabel('Age Group')
plt.ylabel('Churn Rate (%)')
plt.ylim(0, 75)
plt.legend(title='Geography')
plt.grid(False)

plt.tight_layout()
plt.show()

print("What I Found:")
print("Churn is particularly high among older customers in Germany. "
      "The 51–65 age group in Germany shows the highest churn rate, "
      "at approximately 67.5%.")
# Out:
# What I Found:
# Churn is particularly high among older customers in Germany. The 51–65 age group in Germany shows the highest churn rate, at approximately 67.5%.

# %%
#age group and active member-churn rate
age_active_churn = (
    df.groupby(['Age_group', 'IsActiveMember'])['Exited']
    .mean()
    .mul(100)
    .reset_index()
)

age_active_churn['Membership Status'] = age_active_churn['IsActiveMember'].map({
    0: 'Inactive',
    1: 'Active'
})

plt.figure(figsize=(9, 5))

ax = sns.barplot(
    data=age_active_churn,
    x='Age_group',
    y='Exited',
    hue='Membership Status'
)

plt.title('Churn Rate by Age Group and Membership Status', fontsize=14)
plt.xlabel('Age Group')
plt.ylabel('Churn Rate (%)')
plt.ylim(0, 95)
plt.legend(title='Membership Status')
plt.grid(False)

plt.tight_layout()
plt.show()

print("What I Found:")
print("Inactive customers generally show higher churn than active customers. "
      "The difference is especially large in the 51–65 age group, "
      "where inactive customers have a churn rate of approximately 86.8%.")
# Out:
# What I Found:
# Inactive customers generally show higher churn than active customers. The difference is especially large in the 51–65 age group, where inactive customers have a churn rate of approximately 86.8%.

# %%
for col in numerical_cols:
    plt.figure(figsize=(7,4))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
from IPython.display import display, Markdown

distribution_findings = {
    'CreditScore':
        "Most customers have credit scores concentrated around the middle range, with fewer customers at very low or very high scores.",

    'Age':
        "The customer base is mainly concentrated around the 30–40 age range, while older customers are less frequent.",

    'Tenure':
        "Customers are distributed across different tenure levels, with no major concentration at a single tenure value.",

    'Balance':
        "A substantial number of customers have zero balance, while customers with balances show a wide range of account balances.",

    'NumOfProducts':
        "Most customers have 1 or 2 products. Customers with 3 or 4 products represent much smaller segments.",

    'EstimatedSalary':
        "Estimated salaries are spread across a wide range, with no strong concentration at a particular salary level."
}

for col in numerical_cols:
    plt.figure(figsize=(8, 4.5))

    if col == 'Tenure':
        sns.histplot(
            data=df,
            x=col,
            bins=11,
            kde=True
        )
        plt.xticks(range(0, 11))
    else:
        sns.histplot(
            data=df,
            x=col,
            kde=True,
            bins=30
        )

    plt.title(f'Distribution of {col}', fontsize=14)
    plt.xlabel(col)
    plt.ylabel('Number of Customers')
    plt.grid(axis='y', alpha=0.2)
    plt.tight_layout()
    plt.show()
    display(Markdown(
        f"**What I Found:** {distribution_findings[col]}"
    ))
# Out:
# **What I Found:** Most customers have credit scores concentrated around the middle range, with fewer customers at very low or very high scores.
# **What I Found:** The customer base is mainly concentrated around the 30–40 age range, while older customers are less frequent.
# **What I Found:** Customers are distributed across different tenure levels, with no major concentration at a single tenure value.
# **What I Found:** A substantial number of customers have zero balance, while customers with balances show a wide range of account balances.
# **What I Found:** Most customers have 1 or 2 products. Customers with 3 or 4 products represent much smaller segments.
# **What I Found:** Estimated salaries are spread across a wide range, with no strong concentration at a particular salary level.

# %%
boxplot_findings = {
    'CreditScore':
        "The average credit score is slightly lower among churned customers, indicating only a small difference between the two groups.",

    'Age':
        "Churned customers have a noticeably higher average age than retained customers, making age an important variable to investigate further.",

    'Tenure':
        "Average tenure is very similar between retained and churned customers, suggesting no major difference based on tenure alone.",

    'Balance':
        "Churned customers have a higher average balance than retained customers, although balance alone does not explain churn.",

    'NumOfProducts':
        "The average number of products is slightly lower among churned customers, but product-level analysis shows that some smaller product segments have very high observed churn rates.",

    'EstimatedSalary':
        "Average estimated salary is similar between retained and churned customers, suggesting a weak relationship with churn."
}

for col in numerical_cols:
    plt.figure(figsize=(8, 4.5))

    ax = sns.boxplot(
        data=df,
        x='Exited',
        y=col
    )

    ax.set_xticks([0, 1])
    ax.set_xticklabels(['Retained', 'Churned'])

    plt.title(f'{col} vs Customer Churn', fontsize=14)
    plt.xlabel('Customer Status')
    plt.ylabel(col)
    plt.grid(axis='y', alpha=0.2)
    plt.tight_layout()
    plt.show()

    display(Markdown(
        f"**What I Found:** {boxplot_findings[col]}"
    ))
# Out:
# **What I Found:** The average credit score is slightly lower among churned customers, indicating only a small difference between the two groups.
# **What I Found:** Churned customers have a noticeably higher average age than retained customers, making age an important variable to investigate further.
# **What I Found:** Average tenure is very similar between retained and churned customers, suggesting no major difference based on tenure alone.
# **What I Found:** Churned customers have a higher average balance than retained customers, although balance alone does not explain churn.
# **What I Found:** The average number of products is slightly lower among churned customers, but product-level analysis shows that some smaller product segments have very high observed churn rates.
# **What I Found:** Average estimated salary is similar between retained and churned customers, suggesting a weak relationship with churn.

# %%
# correlation heatmap
plt.figure(figsize=(10, 7))

corr = df[numerical_cols + ['Exited']].corr()

sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title('Correlation Heatmap', fontsize=15)
plt.xlabel('Variables')
plt.ylabel('Variables')
plt.tight_layout()
plt.show()

display(Markdown("""
**What I Found:** Age has the strongest positive correlation with customer churn
among the numerical variables, with a correlation of approximately **0.285**.
Balance shows a weaker positive correlation of approximately **0.119**, while
the remaining numerical variables have correlations close to zero.

**Note:** Correlation indicates association and does not establish causation.
"""))
# Out:
# **What I Found:** Age has the strongest positive correlation with customer churn
# among the numerical variables, with a correlation of approximately **0.285**.
# Balance shows a weaker positive correlation of approximately **0.119**, while
# the remaining numerical variables have correlations close to zero.
#
# **Note:** Correlation indicates association and does not establish causation.

# %%
corr = df[numerical_cols + ['Exited']].corr()

corr['Exited'].sort_values(ascending=False)
# Out:
# Exited             1.000000
# Age                0.285323
# Balance            0.118533
# EstimatedSalary    0.012097
# Tenure            -0.014001
# CreditScore       -0.027094
# NumOfProducts     -0.047820
# Name: Exited, dtype: float64

# %% [markdown]
# # Key EDA Insights
#
# ### 1. Overall Churn
#
# * The overall customer churn rate is approximately **20.37%**, indicating that around one-fifth of the customers have exited.
#
# ### 2. Geography-wise Churn
#
# * **Germany** has the highest churn rate compared with France and Spain.
# * France and Spain show relatively lower churn rates.
#
# ### 3. Gender-wise Churn
#
# * Churn rates between male and female customers show a difference, with female customers having a somewhat higher churn rate in this dataset.
#
# ### 4. Age Group-wise Churn
#
# * Churn varies considerably across age groups.
# * The **51–65 age group** shows the highest churn rate.
# * Younger age groups generally show lower churn rates.
#
# ### 5. Active Member-wise Churn
#
# * **Inactive members have a higher churn rate than active members.**
# * This suggests that customer engagement is associated with differences in churn levels.
#
# ### 6. Number of Products-wise Churn
#
# * Customers with **1 product** have a higher churn rate than customers with 2 products.
# * The churn rate is extremely high for customers with **3 and 4 products**.
# * These groups should be investigated further along with their customer counts because their sample sizes may be smaller.
#
# ### 7. Tenure-wise Churn
#
# * Churn rates vary across different tenure levels, but there is no strong consistent increasing or decreasing pattern.
#
# ### 8. Credit Score-wise Churn
#
# * Customers in the **low credit score group** have a somewhat higher churn rate than medium and high credit score groups.
# * However, the difference is relatively small.
#
# ### 9. Balance-wise Churn
#
# * Churn varies across balance groups.
# * The **Low Balance** group shows the highest churn rate among the defined balance categories.
# * Customers with no balance show a comparatively lower churn rate.
#
# ### 10. Credit Card-wise Churn
#
# * Customers with and without a credit card have very similar churn rates.
# * Therefore, credit card ownership does not show a major difference in churn in this analysis.
#
# ### 11. Age and Geography Analysis
#
# * Combining age group with geography reveals stronger differences than looking at either variable separately.
# * Older customers, particularly in **Germany**, show substantially higher churn rates.
#
# ### 12. Age and Active Membership Analysis
#
# * Combining age with active membership shows that **inactive customers in older age groups** have particularly high churn rates.
# * The difference between active and inactive customers is especially noticeable in the 51–65 age group.
#
# ### 13. Credit Score and Geography Analysis
#
# * Churn patterns vary when credit score groups are analyzed together with geography.
# * Geography appears to create differences in churn across credit score groups.
#
# ### 14. Balance and Geography Analysis
#
# * Balance-related churn patterns also differ across countries.
# * This indicates that balance and geography together provide more detailed customer segmentation than either variable alone.
#
# ### 15. Product Count and Active Membership Analysis
#
# * Churn varies when the number of products is considered together with active membership.
# * This helps identify customer segments where product count and engagement may jointly be associated with higher churn.
#
# ### 16. Numerical Variables: Churned vs Retained Customers
#
# * Churned customers have a higher **average age** than retained customers.
# * Churned customers also have a higher **average balance**.
# * Average credit score, tenure, number of products and estimated salary show comparatively smaller differences between churned and retained customers.
#
# ### 17. Correlation Analysis
#
# * **Age has the strongest positive correlation with churn (0.285)** among the numerical variables analyzed.
# * Balance has a weak positive correlation with churn (**0.119**).
# * Estimated Salary, Tenure, Credit Score and Number of Products have correlations close to zero with churn.
# * Correlation indicates association and does not imply causation.

# %% [markdown]
# # Business Recommendations
#
# ### 1. Focus on High-Risk Age Groups
#
# * Customers in older age groups, particularly **51–65**, show substantially higher churn rates.
# * The bank can consider targeted retention programs, personalized communication, and regular customer engagement for these segments.
#
# ### 2. Improve Customer Engagement
#
# * Inactive members have a higher churn rate than active members.
# * The bank can use personalized offers, relevant product information, and engagement campaigns to encourage inactive customers to use banking services more regularly.
#
# ### 3. Investigate Germany-Specific Churn
#
# * Germany has a substantially higher churn rate than France and Spain.
# * The bank should investigate Germany-specific factors such as customer experience, product preferences, service issues, and competitive conditions before designing targeted retention strategies.
#
# ### 4. Monitor High-Risk Product Segments
#
# * Customers with **3 or 4 products** show very high observed churn rates.
# * These groups should be investigated further, including checking their sample sizes and customer characteristics, before implementing specific retention actions.
#
# ### 5. Strengthen Customer Retention for High-Risk Segments
#
# * Customers identified through combinations such as **older age + inactive membership + high-churn geography** can be prioritized for closer monitoring and personalized retention communication.
#
# ### 6. Use Customer Segmentation
#
# * Instead of applying the same retention strategy to all customers, the bank can segment customers using factors such as **age, geography, activity status, balance, and number of products**.
# * This can help design more targeted customer retention campaigns.
#
# ### 7. Monitor Churn Indicators Regularly
#
# * The bank can build a recurring churn monitoring process using customer activity, demographic information, product usage, and account characteristics.
# * Regular monitoring can help identify changing churn patterns and support timely retention efforts.

# %% [markdown]
# # Conclusion
#
# This customer churn analysis provides insights into the factors associated with customer churn and helps identify customer segments that require greater attention.
#
# The analysis shows an overall churn rate of approximately **20.37%**. Age, geography, customer activity, balance, and number of products show noticeable differences in churn rates across different customer segments. In particular, older customers, inactive members, and customers in Germany show higher observed churn rates.
#
# The correlation analysis also shows that **Age has the strongest positive correlation with churn (0.285)** among the numerical variables analyzed, while Balance has a weaker positive correlation.
#
# These findings can help the bank identify high-risk customer segments, improve customer engagement, and develop more targeted retention strategies. Further analysis using predictive modeling could be used to estimate the churn probability of individual customers.
